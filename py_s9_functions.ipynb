# %% [markdown]
# #### functions :
# - a block of code which we can use many times

# %% [markdown]
# ### syntax for fuctions:
# - "def <fuction_name>(<name_of_attribute(or)attributes>(or)none in the brackets):"
# -

# %%
def addition():
    num1 = 10
    num2 = 20
    add = num1+num2
    print(add)
addition()# this type of functions are called functions without arguments...
# Out:
# 30

# %% [markdown]
# ### tip :
# - you can write a normal code then convert it into a function

# %% [markdown]
# ### note:
# - function names can be anything
# - same rules applicabe as variable rules
# - whenever you create the functiion make sure the indentation correctly
# - starting with keyword ending with colon then code line start with indentation
# - brackets means functins
# - never missed the brackets whenever you call a function
# - if you want to execute the code we need to call the functions
# - while you are calling the function if you see function or bound method means that we missed the brackets
# - and after creating functions we can almost use them anytime and enywhere

# %% [markdown]
# ### very imp note:
# -  when ever we define a fuction python will not throw any error unless we will call the fuction if it has some error
# -  thats why making a code then converting the code to function will be helpull sometimes
# -  function name and variable name should not be same if it is then its problementing....

# %%
def area_circle(radius):
    pi = 3.14
    area = round(pi*radius**2)
    print(f"the area of circle is : {area}")
    return area#this will  do the same  as print too but if you take normal input variables you have return them or they will give none...
radius = eval(input("enter the radius of circle :"))
area_circle(radius)
# Out:
# enter the radius of circle : 22
# the area of circle is : 1520
# 1520

# %%
#here you got no error in the code because you didn't take input in the function again
# also you have passed the value of radius as an argument to do the fuction and return the value

# %%
#function acts like a wrapper for the code as wrapper for chocolate

# %% [markdown]
# ### note for fun with args:
# - when ever we want to create functions look at how many variables are there.
# - look how many input variables are there and output variables are there.

# %%
def addition1(n1,n2):
    add = n1+ n2
    print(f"the addition of {n1} and {n2} :{add}")
addition1(100,200)#you can give the n1,n2 values directly or you can enter them as using input statements
# Out:
# the addition of 100 and 200 :300

# %%
#using the variable name and fuction name similarly might work but its a bad practice in the long run.

# %% [markdown]
# **default arguments**

# %%
def total_price():
    tip_amount = round(meal_price*tip_percent/100)
    print("the tip price :"+str(int(tip_amount)))
    print("the total amount :"+str(int(meal_price+tip_amount)))

meal_price = eval(input("enter the meal price :"))
tip_percent = eval(input("enter the tip percentage :"))
total_price()
# Out:
# enter the meal price : 1000
# enter the tip percentage : 10
# the tip price :100
# the total amount :1100

# %%
def total_price(meal_price,tip_percent):
    tip_amount = round(meal_price*tip_percent/100)
    print("the tip price :"+str(int(tip_amount)))
    print("the total amount :"+str(int(meal_price+tip_amount)))

meal_price = eval(input("enter the meal price :"))
tip_percent = eval(input("enter the tip percentage :"))
total_price(meal_price,tip_percent)
# Out:
# enter the meal price : 1200
# enter the tip percentage : 20
# the tip price :240
# the total amount :1440

# %%
#when we provide value as arguments in the brackets we call it default argument.

# %%
#case3:
def addition(n1,n2 = 600):# here we are giving a default number 600 if no value is given for n2 it will take the defalult value
    n2 = 2000
    add = n1+n2
    print(add)
n2 = 3000
addition(500,1000)
# Out:
# 2500

# %% [markdown]
# **local variable and global variable**
# - local variable means : the variables inside the function call
# - glabal variable means : the variables outside the function call
# - once you define the variables outside means , you can use those vaariale anywhere
# - you can use the global variables inside function also
# - but you cannot use local variables outside the function

# %%
def multiplication():
    a_1 = 10
    b_1 = 20
    mul = a_1*b_1
    print(mul)
multiplication()#this problem is the example of using local variable

# a,b are local variable so these we cannot use outside the function ,they will throw error
# Out:
# 200

# %%
a_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 a_1
#
# NameError: name 'a_1' is not defined

# %%
a_1 = 10
b_1 = 20
def multiplication():
    mul = a_1*b_1
    print(mul)
multiplication()#this probldm is example of using global variable
# Out:
# 200

# %%
a_1
# Out:
# 10

# %%
##learn the different cases of defining a function

# %%
#case_7
a1 = 100
b1 = 200
def add11(a1=1000):
    a1 = 5000
    add1 = a1+b1
    print(add1)
add11(a1 = 2000)
# Out:
# 5200

# %%
s = 0 #gv
def add():
    s = s + 10 #lv
    print(s)
add()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 5
#       3     s = s + 10 #lv
#       4     print(s)
# ----> 5 add()
#
# Cell In[1], line 3, in add()
#       2 def add():
# ----> 3     s = s + 10 #lv
#       4     print(s)
#
# UnboundLocalError: cannot access local variable 's' where it is not associated with a value

# %%
s = 0 #gv
def add():
    c = 0
    s = c + 10 #lv #if you try to use an global variable inside the function and outside the function it will confuse it for local variable
    print(s)
add()
# Out:
# 10

# %%
**note**
- if you lgive same variable as global and local
- make sure that varaible l

# %%
n11 = 10
def addition():
    n2 = 200+n11
    n3 = n11+n2
    print(n11,n2,n3)

addition()
# Out:
# 10 210 220

# %%
s = 0
def add():
    c = s+10
    s = c #lv
    print(s)
add()

#step1 :s=0  gv
#step2 :define the function
#step-3 :call the function
#step4 :run the program
#         c is lv : c = s+10 = c = 10
# we are creating a new variable
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 6
#       4     s = c #lv
#       5     print(s)
# ----> 6 add()
#       8 #step1 :s=0  gv
#       9 #step2 :define the function
#      10 #step-3 :call the function
#      11 #step4 :run the program
#      12 #         c is lv : c = s+10 = c = 10
#
# Cell In[7], line 3, in add()
#       2 def add():
# ----> 3     c = s+10
#       4     s = c #lv
#       5     print(s)
#
# UnboundLocalError: cannot access local variable 's' where it is not associated with a value

# %%
value = 100
def great():
    global value#this is a tag
    value = 200
    print('hello')
greet()
print('value:',value)

# %%
**global**
- global keyword is used to take the local ariable value outside

# %%
n11 = 10
def addition():
    global n11#we gave this because we want the program to not confuse it with local
    n22 = 200
    n33 = n11+n22
    print(n11,n22,n33)

addition()
# Out:
# 10 200 210

# %%
n33
# Out:
# 210

# %%
def average():
    n1 = 10
    n2 = 20
    n3 = 30
    avg = (n1+n2+n3)/3
    return(avg,n3)
avg,n3 = average()
#how many values we are returnijng
#we wil store each return values in different values in different variable

# %%
print(avg)
print(n3)
# Out:
# 20.0
# 30

# %%
#return always at last line of the function not the middele lines
# we use return in most of real time problems

# %%
num1 = 10
def fun1():
    print(num)

# %%
num2 = 10
def fun2():
    print(num2)
    num2 = 100 #lv

fun2()#unbound local variable is where we are access a local variable without assigning it
#and we are give the same variabe in as global and local variables
#thinkk you  dont have the global variable with the same name and try to anlyze the code if its correct or not
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[4], line 6
#       3     print(num2)
#       4     num2 = 100 #lv
# ----> 6 fun2()#unbound local variable is where we are access a local variable without assigning it
#       7 #and we are give the same variabe in as global and local variables
#       8 #thinkk you  dont have the global variable with the same name and try to anlyze the code if its correct or not
#
# Cell In[4], line 3, in fun2()
#       2 def fun2():
# ----> 3     print(num2)
#       4     num2 = 100
#
# UnboundLocalError: cannot access local variable 'num2' where it is not associated with a value

# %%
# to convert a local variable outise as a global variable use global 
a1 = 100
b1 = 200
def add11():
    add1 = a1+b1
    print(add1)
add11()
# Out:
# 300

# %%
a1 = 200
b1 = 400
def add12():
    a1 = 250
    b1 = 250
    add2 = a1+b1
    print(add2)
add12()
# Out:
# 500

# %%
a1 = 200
b1 = 400
def add12():
    add2 = a1+b1
    print(add2)
    a1 = 250
    b1 = 250
add12()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[8], line 8
#       6     a1 = 250
#       7     b1 = 250
# ----> 8 add12()
#
# Cell In[8], line 4, in add12()
#       3 def add12():
# ----> 4     add2 = a1+b1
#       5     print(add2)
#       6     a1 = 250
#
# UnboundLocalError: cannot access local variable 'a1' where it is not associated with a value

# %%
def greet1():
    print('hello good morning')

def greet2():
    print("good night")
greet1()
greet2()
# Out:
# hello good morning
# good night

# %%
def greet1():
    print('hello good morning')
    greet2()
def greet2():
    print("good night")
    greet1()
    
greet1()
# Out:
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# ...

# %%
#first create 4 individual function.
#fun1:add
#fun2:sub
#fun3:mul
#fun4:div

# create a main func
# inside main function
# print some statements
#option1 : addition
#option2 : sub
#option3 : mul
#option4 : div
#option = eval(input('1-4'))
#a value
#b value
#if option == 1
#     add function
#elif option == 2
#     add function
#elif option == 3
#     add function
#elif option == 4
#      add function

# %%
def add(a,b):
    add = a+b#so you can use the same name as the function name  as a variable....but it has its limits
    print(add)
add(2,8)
# Out:
# 10

# %%
def add():
    print(a+b)
def sub():
    print(a-b)
def mul():
    print(a*b)
def div():
    print(a/b)
a = int(input("enter a num a :"))
b = int(input("enter a num b :"))
option = int(input("enter the option from 1 to 4 :"))
while option < 1 or option > 4:
    print("choose a valid option")
    option = int(input("enter the option from 1 to 4 :"))
if option == 1:
    add()
elif option == 2:
    sub()
elif option == 3:
    mul()
elif option == 4:
    div()
# Out:
# enter a num a : 4
# enter a num b : 9
# enter the option from 1 to 4 : 2
# -5
